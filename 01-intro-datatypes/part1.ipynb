# %% [markdown]
# ## Print
#
# A computer executes commands one by one. Among other things, commands can be used to:
#
# - perform calculations
# - compare things in the computer's memory
# - cause changes in how the program functions
# - relay messages or ask for information from the program's user.
#
# let's begin by printing text (show some text on the screen)

# %%
print("Hi there!") # put them in quotes or will not work
# Out:
# Hi there!

# %%
print("Welcome to Introduction to Programming!")
print("First we will practice using the print command.")
print("This program prints three lines of text on the screen.")
# Out:
# Welcome to Introduction to Programming!
# First we will practice using the print command.
# This program prints three lines of text on the screen.

# %% [markdown]
# ## Arithmetic operations
#
# Notice the lack of quotation marks around the arithmetic operations above.
#
# Quotation marks are used to signify strings.
#
# In programming, strings are sequences of characters.

# %%
# + * / are called operators in pythons - they do operations on their both sides and returns the result
print(2 + 5)
print(3 * 3)
print(2 + 2 * 10)
# Out:
# 7
# 9
# 22

# %% [markdown]
# Strings can consist of letters, numbers and any other types of characters, such as punctuation.
#
# Strings aren't just words as we commonly understand them, but instead a single string can be as long as multiple complete sentences.
#
# Strings are usually printed out exactly as they are written.

# %%
print(2 + 2 * 10)
print("2 + 2 * 10")
# Out:
# 22
# 2 + 2 * 10

# %% [markdown]
# # Python Variables
#
# variable are way to refer to some values so it can be used later

# %%
x = 10 # hard-coded as opposed to user input
print(x)
# Out:
# 10

# %%
x = "hello"
print(x)
# Out:
# hello

# %% [markdown]
# variable names
# - are case sensitive
# - must start with a letter or an underscore
# - cannot start with a number
# - can only contain alpha numeric characters and underscores
# - are a way to refer to data values
#
# some words are reserved keywords for the python language and cannot be used as variable names
# meaning they are reserved for special use by the python language. like `for`, `print`, .etc
#
# A variable is a connection between a name in the code and some data in memory.

# %% [markdown]
# The reason we call it a variable is because it is able to vary.
# We can first say that this name refers to some data in one place in memory,
# but then later in our program we could change it so that the same name refers to some other data in a different location.

# %% [markdown]
# that make python what is called a **dynamically typed** language
# this means the type of the variable can be changed during the execution of the program (runtime)
# the type of the variable is determined by the value assigned to it

# %%
x = 10
x = "hello"
print(x)
# Out:
# hello

# %% [markdown]
# there are other data types in python
# for example
# - `x = 10` int data type
# - `x = "hello"` str data type
# - `x = 10.5` float data type
# - `x = True` bool data type
# - `x = None` None data type - no value
#
# any other type of value not listed in these previous examples is a user defined data type (class)
# meaning that it is a custom data type that we can define and use, and each value of that type is called an instance (object) of that class

# %% [markdown]
# spacing in python is important and is used to separate code into different blocks of code (groups of statements) as we will see in loops and if statements

# %% [markdown]
# ## Integer Values - int data type
#
# Integers are numbers that do not have a decimal or fractional part, such as `-15`, `0` and `1`

# %%
number = 3
double_the_number = number * 2
print(double_the_number)
# Out:
# 6

# %%
number = number + 15
print(number)
# Out:
# 18

# %%
number += 1
print(number)
# Out:
# 19

# %%
number *= 2
print(number)
# Out:
# 38

# %% [markdown]
# Notice the lack of **quotation marks** here. In fact, if we were to add quotation marks around the number, this would mean our variable would no longer be an integer, but a string instead. A string can contain numbers, but it is processed differently.

# %%
number1 = 100
number2 = "100"

print(number1)
print(number2)
# Out:
# 100
# 100

# %% [markdown]
# Variable types matter because different operations affect different types of variables in different ways. Let's have a look at an example:

# %%
number1 = 100 # + operator means addition
number2 = "100" # means concatenation, or "stringing together"

print(number1 + number1)
print(number2 + number2)
# Out:
# 200
# 100100

# %% [markdown]
# Not all operators are available for all types of variables. While numbers can be divided using the division operator /, attempting to divide a string by a number causes an error:

# %%
number = "100"
print(number / 2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 2
#       1 number = "100"
# ----> 2 print(number / 2)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# ## Strings (str)
# - are sequences of characters
# - written in double quotes or single quotes
# - immutable (cannot be changed)
# - used to represent text

# %%
name = "john"
print(name)
# Out:
# john

# %%
# add (concatenate) " Doe" to "john"
name += " Doe"
print(name)
# Out:
# john Doe Doe

# %%
# print "Hi " 3 times as a single string
print("Hi " * 3)
# Out:
# Hi Hi Hi

# %%
# generates an error
print(3 + "hello")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 # generates and error
# ----> 2 print(3 + "hello")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# ## Combining values when printing
#
# Similarly, the following program will not work, because "The result is " and result are of two different types:

# %%
result = 10 * 25
# the following line produces an error
print("The result is " + result)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 3
#       1 result = 10 * 25
#       2 # the following line produces an error
# ----> 3 print("The result is " + result)
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# the integer can be cast as a string with the str function, and the two strings can then be combined normally

# %%
result = 10 * 25
print("The result is " + str(result))
# Out:
# The result is 250

# %% [markdown]
# The print command also has built-in functionalities that support combining different types of values.

# %%
result = 10 * 25
print("The result is", result)
# Out:
# The result is 250

# %%
# generates an error
print("hi" * 'hi')

# %% [markdown]
# error message does not mean you are a bad programmer
# instead it means the computer can't understand your code
# use errors to help yourself learn and grow

# %% [markdown]
# strings can be enclosed between single `'name'`or double `"name"`or triple `"""name"""`quotes to denote that is a string
# is the string we are trying to print is a multiline string or has `'` or `"` in it then we need to use triple quotes

# %%
person = 'amy'
para = """amy's car "bmw" is new"""
para

# %% [markdown]
# triple quotes can be used as a way to denote documenations. you can find them in the beginning of the file or in the beginning of a function.
# for example, the numpy library uses triple quotes to document functions and files (modules). see [here](https://github.com/numpy/numpy/blob/main/numpy/__init__.py).

# %%
"""
    This is the doc string of this module (file/package)
    It's used to describe the functionality (usage) of the module,
    and provide detailed descriptions of code for users

    this doc string is often processed by developers tools like Sphinx to generate documentation
    for more information see: https://www.datacamp.com/tutorial/docstrings-python
    and https://www.python.org/dev/peps/pep-0257/

    while comments are used in general to explain context and provide background
    for a specific block of code, docstrings are used to document the entire module
    function, or class (user-defined data type)

    documentation includes use cases, parameters, and return values

    comments can be used also as a way to disable sections of code
    so that they are not executed by the interpreter when the program is run

    the interpreter is a program that reads your python code and executes it
    by translating it into machine code (zeros and ones '001001110') and running it
    line by line in real-time.
"""
# Out:
# "\n    This is the doc string of this module (file/package)\n    It's used to describe the functionality (usage) of the module,\n    and provide detailed descriptions of code for users\n\n    this doc string is often processed by developers tools like Sphinx to generate documentation\n    for more information see: https://www.datacamp.com/tutorial/docstrings-python\n    and https://www.python.org/dev/peps/pep-0257/\n\n    while comments are used in general to explain context and provide background\n    for a specific block of code, docstrings are used to document the entire module\n    function, or class (user-defined data type)\n\n    documentation includes use cases, parameters, and return values\n\n    comments can be used also as a way to disable sections of code\n    so that they are not executed by the interpreter when the program is run\n\n    the interpreter is a program that reads your python code and executes it\n    by translating it into machine code (zeros and ones '0010
# ...

# %% [markdown]
# ## Floating point numbers (float)
#
# refers to numbers with a decimal point
#
# - are real numbers
# - they are written with decimal points
# - they are used to represent numbers with decimal places
# - float (floating point) values

# %%
pi = 3.14159
print(pi)
# Out:
# 3.14159

# %%
r = 5
cim = 2 * pi * r
area = pi * (r**2)
print(cim, area)

# %% [markdown]
# # Complex numbers
#
# - written with the j symbol
# - used to represent complex numbers

# %%
complex_number = 2 + 3j
print(complex_number)
# Out:
# (2+3j)

# %%
complex_number = 2 + 3j
other_complex = 1 + 4j
print(complex_number + other_complex)

# %% [markdown]
# # Boolean Types
#
# Variables of type bool can only have two values: True or False.
#
# used primarily for conditional statements (if, elif, else statements)
#
# they say if the condition is `true` or `false`

# %%
a = 3
condition = a < 5
print(condition)
# Out:
# True

# %%
print(15 == 15)
print(10 < 3)
print(10 <= 3)
# Out:
# True
# False
# False

# %%
is_raining = True
if is_raining:
    print("It's raining outside")
else:
    print("It's not raining outside")
# Out:
# It's raining outside

# %% [markdown]
# as there is binary operators for int and float data types like +, -, *, /, //, %, ** used to do arithmitic operations
#
# there is aslo conditional operators like ==, !=, >, <, >=, <=, and, or, not used to do boolean operations on values of boolean data types

# %%
is_cloudy = False
if is_cloudy and is_raining:
    print("It's cloudy and raining outside")
else:
    print("It's not cloudy or raining outside")
# Out:
# It's not cloudy or raining outside

# %% [markdown]
# # None Type
#
# - used to represent the absence of a value
# - used to represent the absence of a variable

# %%
x = None
print(x)
# Out:
# None

# %% [markdown]
# setting a variable to `None` can be used to dereference a variable. meaning that the variable is no longer pointing to any value

# %%
first_list = [1, 2, 3]
second_list = first_list
first_list = None

print(first_list)
print(second_list)

# %% [markdown]
# ## Type annotations
#
# in python, we can still indicate the type of the value inside our variable using type annotations

# %%
x: int = 5
print(x)
# Out:
# 5

# %% [markdown]
# but it will not generate errors when we assigned the variable a different type

# %%
x = "hi"
print(x)
# Out:
# hi

# %% [markdown]
# ## Getting input from the user
#
# Input refers to any information a user gives to the program. Specifically, the Python command input reads in a line of input typed in by the user. It may also be used to display a message to the user, to prompt for specific input.

# %%
name = input("What is your name? ") # name refers to the string returned from the user
print("Hi there, " + name) # here we are adding two strings together (string concatenation)
# Out:
# Hi there, kareim

# %% [markdown]
# If the same variable is used to store more than one input, each new value will replace the previous one.

# %%
address = input("What is your address? ")
print("So you live at address " + address)

address = input("Please type in a new address: ")
print("Your address is now " + address)

# %% [markdown]
# ## Printing with f-strings
#
# What if we want to have more flexibility and control over what we print out? So called f-strings are another way of formatting printouts in Python. The syntax can initially look a bit confusing, but in the end f-strings are often the simplest way of formatting text.
#
# Let's break this apart. In the very beginning of the string we are printing out there is the character f. This tells Python that what follows is an f-string. Within the string, enclosed in curly brackets, is the variable name result. The value it contains becomes a part of the printed string. The printout is exactly the same as in the previous examples:

# %%
result = 10 * 25
print(f"The result is {result}")
# Out:
# The result is 250

# %%
name = "Mark"
age = 37
city = "Palo Alto"
print(f"Hi {name}, you are {age} years old. You live in {city}.")
# Out:
# Hi Mark, you are 37 years old. You live in Palo Alto.

# %% [markdown]
# the old school way is hard but still works

# %%
name = "Mark"
age = 37
city = "Palo Alto"
print("Hi", name, ", you are", age, "years old. You live in", city, ".")
# Out:
# Hi Mark , you are 37 years old. You live in Palo Alto .

# %% [markdown]
# ## Literals - Terminology
#
# - Literals are fixed values that are directly used in the code.
# - They represent specific values like numbers, strings, or Boolean values.

# %%
3.14
# Out:
# 3.14

# %%
"cake" # cake is now a literal string and not a variable
# not a name that we use to refer to something else
# Out:
# 'cake'

# %%
food = "cake"
food # variables store literals - literals are literal values, they can't be changed
# Out:
# 'cake'

# %%
"number" = 10
# Out:
#   Cell In[21], line 1
#     "number" = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
x = 5  # Here, 'x' is a variable storing the integer value 5
x = "Hello"  # Now, 'x' stores the string "Hello"

num = 10  # Here, '10' is a numeric literal assigned to the variable 'num'
message = 'Welcome'  # 'Welcome' is a string literal assigned to 'message'
